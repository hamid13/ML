# %%
import numpy as np
from numpy.linalg import inv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

np.random.seed(42)
X = np.random.randn(500,1)
y = 2*X + 1 + 1.2*np.random.randn(500,1)
X.shape, y.shape
# Out:
# ((500, 1), (500, 1))

# %%
plt.rcParams['figure.figsize'] = (12.0, 9.0)
plt.scatter(X, y)
plt.show()

# %%
def find_theta(X, y):

    m = X.shape[0]                                              # Number of training examples.
    X = np.append(X, np.ones((m,1)), axis=1)                    # Appending a column of one's in X to add the bias term.
    y = y.reshape(m,1)                                           # reshaping y to (m,1)

    # The Normal Equation
    theta = np.dot(np.linalg.inv(np.dot(X.T, X)), np.dot(X.T, y))
    return theta


def predict(X):
    X = np.append(X, np.ones((X.shape[0],1)), axis=1)             # Appending a cloumn of ones in X to add the bias term.
    preds = np.dot(X, theta)                                      # preds is y_hat which is the dot product of X and theta.
    return preds

# %%
# Getting the Value of theta using the find_theta function.
theta = find_theta(X, y)
print(theta)
# Out:
# [[1.90949642]
#  [1.0388102 ]]

# %%
# Getting the predictions on X using the predict function.
preds = predict(X)
# Plotting the predictions.
fig = plt.figure(figsize=(8,6))
plt.plot(X, y, 'b.')
plt.plot(X, preds, 'c-')
plt.xlabel('X - Input')
plt.ylabel('y - target / true')
# Out:
# Text(0, 0.5, 'y - target / true')
